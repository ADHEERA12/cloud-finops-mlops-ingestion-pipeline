# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/telemetry_data.csv")
df.head()
# Out:
#    cpu_usage  memory_usage  requests_per_sec   network_io  pod_count  \
# 0  41.835910     25.165731       7326.983279  3208.815613          1
# 1  90.810716     22.640550       1926.668756  2323.497645          3
# 2  72.219485     12.921543       3531.732974  4824.267698         13
# 3  60.885971     39.650534       6666.478305  1133.943332          7
# 4  23.261584     31.550698       4872.684511  2959.889259          6
#
#     cloud_cost
# 0   723.876972
# 1   487.566797
# 2  1033.467698
# 3   373.606924
# 4   669.549858

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cpu_usage         10000 non-null  float64
#  1   memory_usage      10000 non-null  float64
#  2   requests_per_sec  10000 non-null  float64
#  3   network_io        10000 non-null  float64
#  4   pod_count         10000 non-null  int64
#  5   cloud_cost        10000 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 468.9 KB

# %%
df.isnull().sum()
# Out:
# cpu_usage           0
# memory_usage        0
# requests_per_sec    0
# network_io          0
# pod_count           0
# cloud_cost          0
# dtype: int64

# %%
df.describe()
# Out:
#           cpu_usage  memory_usage  requests_per_sec    network_io  \
# count  10000.000000  10000.000000      10000.000000  10000.000000
# mean      52.003562     33.280852       5050.498906   2518.631246
# std       24.448561     17.936262       2839.060197   1430.523224
# min       10.000989      2.009780        100.476427     50.027407
# 25%       30.937954     17.744640       2612.104320   1271.943382
# 50%       51.864932     33.365600       5070.474137   2525.149685
# 75%       72.900540     48.901712       7472.271154   3748.225457
# max       94.976002     63.995339       9999.019672   4998.957390
#
#           pod_count    cloud_cost
# count  10000.000000  10000.000000
# mean       9.952600    606.579830
# std        5.472125    288.382397
# min        1.000000     34.184342
# 25%        5.000000    358.239099
# 50%       10.000000    606.686867
# 75%       15.000000    852.932341
# max       19.000000   1184.615466

# %%
sns.histplot(df["cloud_cost"], kde=True)
plt.show()

# %%
corr = df.corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True)
plt.show()

# %%
sns.scatterplot(
    x=df["cpu_usage"],
    y=df["cloud_cost"]
)

plt.show()
